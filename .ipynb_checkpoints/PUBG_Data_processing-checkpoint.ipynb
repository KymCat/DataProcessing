# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as spst

# %%
data = pd.read_csv('../PUBG_WIN_OR_LOSE_DATASET.csv')
data.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  ...  revives  \
# 0         0.00      0              0      0         60  ...        0
# 1        91.47      0              0      0         57  ...        0
# 2        68.00      0              0      0         47  ...        0
# 3        32.90      0              0      0         75  ...        0
# 4       100.00      0              0      0         45  ...        0
#
#    rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# 0        0.0000          0          0.00          0               0
# 1        0.0045          0         11.04          0               0
# 2        0.0000          0          0.00          0               0
# 3        0.0000          0          0.00          0               0
# 4        0.0000          0          0.00          0               0
#
#    walkDistance  weaponsAcquired  winPoints  winPlacePerc
# 0        244.80                1       1466        0.4444
# 1       1434.00                5          0        0.6400
# 2        161.80                2          0        0.7755
# 3        202.70                3          0        0.1667
# 4         49.75                2          0        0.1875
#
# [5 rows x 29 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4446966 entries, 0 to 4446965
# Data columns (total 29 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Id               object
#  1   groupId          object
#  2   matchId          object
#  3   assists          int64
#  4   boosts           int64
#  5   damageDealt      float64
#  6   DBNOs            int64
#  7   headshotKills    int64
#  8   heals            int64
#  9   killPlace        int64
#  10  killPoints       int64
#  11  kills            int64
#  12  killStreaks      int64
#  13  longestKill      float64
#  14  matchDuration    int64
#  15  matchType        object
#  16  maxPlace         int64
#  17  numGroups        int64
#  18  rankPoints       int64
#  19  revives          int64
#  20  rideDistance     float64
#  21  roadKills        int64
#  22  swimDistance     float64
#  23  teamKills        int64
#  24  vehicleDestroys  int64
#  25  walkDistance     float64
#  26  weaponsAcquired  int64
#  27  winPoints        int64
#  28  winPlacePerc     float64
# dtypes: float64(6), int64(19), object(4)
# memory usage: 983.9+ MB

# %%
data.isna().sum() # 결측치 합계
# Out:
# Id                 0
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       1
# dtype: int64

# %%
temp = data.loc[data['winPlacePerc'].notnull()]
temp.isna().sum()
# Out:
# Id                 0
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       0
# dtype: int64

# %%
temp_id_remove = temp.loc[:, 'assists' :]
temp_id_remove.drop('matchType', axis = 1, inplace = True)

# %%
for column_name in temp_id_remove : # t-test
    print(f"{column_name} : ".ljust(20),spst.pearsonr(temp_id_remove[column_name], temp_id_remove['winPlacePerc']))
# Out:
# assists :            PearsonRResult(statistic=0.2994408892598539, pvalue=0.0)
# boosts :             PearsonRResult(statistic=0.6342342507380694, pvalue=0.0)
# damageDealt :        PearsonRResult(statistic=0.44050679763368794, pvalue=0.0)
# DBNOs :              PearsonRResult(statistic=0.2799696924174957, pvalue=0.0)
# headshotKills :      PearsonRResult(statistic=0.27772246274102796, pvalue=0.0)
# heals :              PearsonRResult(statistic=0.42785698570252134, pvalue=0.0)
# killPlace :          PearsonRResult(statistic=-0.7190689184926048, pvalue=0.0)
# killPoints :         PearsonRResult(statistic=0.012908088775843629, pvalue=3.617128536073139e-163)
# kills :              PearsonRResult(statistic=0.41991598708955025, pvalue=0.0)
# killStreaks :        PearsonRResult(statistic=0.37756645960730784, pvalue=0.0)
# longestKill :        PearsonRResult(statistic=0.41015355970609413, pvalue=0.0)
# matchDuration :      PearsonRResult(statistic=-0.005171314235440617, pvalue=1.0879561963867156e-27)
# maxPlace :           PearsonRResult(statistic=0.037377371794820896, pvalue=0.0)
# numGroups :          PearsonRResult(statistic=0.0396207674543277, pvalue=0.0)
# rankPoints :         PearsonRResult(statistic=0.013522686659319296, pvalue=7.067002563682332e-179)
# revives :            PearsonRResult(statistic=0.24088061673432207, pvalue=0.0)
# rideDistance :       PearsonRResult(statistic=0.34291452824687985, pvalue=0.0)
# roadKills :          PearsonRResult(statistic=0.03454376824710499, pvalue=0.0)
# swimDistance :       PearsonRResult(statistic=0.1496073737276381, pvalue=0.0)
# teamKills :          PearsonRResult(statistic=0.015942641616142096, pvalue=8.085234636665894e-248)
# vehicleDestroys :    PearsonRResult(statistic=0.0734361418920375, pvalue=0.0)
# walkDistance :       PearsonRResult(statistic=0.8108875244990067, pvalue=0.0)
# weaponsAcquired :    PearsonRResult(statistic=0.5838061651505904, pvalue=0.0)
# winPoints :          PearsonRResult(statistic=0.00706082803592932, pvalue=3.831458922150764e-50)
# winPlacePerc :       PearsonRResult(statistic=0.9999999999999962, pvalue=0.0)

# %%
#print(data['matchType'].value_counts()) # squad 만 뽑아내자

squad_data = data.loc[data['matchType'] == 'squad']
print("-"*50)
print("length : ",len(squad_data))
print("-"*50)
print(squad_data.isna().sum() if squad_data.isna().all().sum() else "not null")
# Out:
# --------------------------------------------------
# length :  626526
# --------------------------------------------------
# not null

# %%
squad_data.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')

# %%
#print(squad_data.info())

# 승률 예측시 필요없는 열 삭제
# Id groupId matchId matchType matchDuration killPoints winPoints rankPoints REMOVE
remove_list = ['Id', 'groupId', 'matchId', 'matchType', 'matchDuration', 'killPoints', 'winPoints', 'rankPoints']
temp_data = squad_data.copy()
temp_data.drop(remove_list, axis = 1, inplace=True)
    
print(temp_data.info())

# 다중공선성 : 값 10이 넘어가면 다중공선성이 있다고 판단된다 
from statsmodels.stats.outliers_influence import variance_inflation_factor
for i, column in enumerate(temp_data.loc[:,:'weaponsAcquired']) :
    print(f"{column} : ".ljust(20),variance_inflation_factor(temp_data.values, i))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 626526 entries, 8 to 4446952
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   assists          626526 non-null  int64
#  1   boosts           626526 non-null  int64
#  2   damageDealt      626526 non-null  float64
#  3   DBNOs            626526 non-null  int64
#  4   headshotKills    626526 non-null  int64
#  5   heals            626526 non-null  int64
#  6   killPlace        626526 non-null  int64
#  7   kills            626526 non-null  int64
#  8   killStreaks      626526 non-null  int64
#  9   longestKill      626526 non-null  float64
#  10  maxPlace         626526 non-null  int64
#  11  numGroups        626526 non-null  int64
#  12  revives          626526 non-null  int64
#  13  rideDistance     626526 non-null  float64
#  14  roadKills        626526 non-null  int64
#  15  swimDistance     626526 non-null  float64
#  16  teamKills        626526 non-null  int64
#  17  vehicleDestroys  626526 non-null  int64
#  18  walkDistance     626526 non-null  float64
#  19  weaponsAcquired  626526 non-null  int64
#  20  winPlacePerc     626526 non-null  float64
# dtypes: float64(6), int64(15)
# memory usage: 121.3 MB
# None
# assists :            1.55442687020686
# boosts :             3.365725485718272
# damageDealt :        9.689660690336455
# DBNOs :              7.275497834326932
# headshotKills :      2.0885848608913546
# heals :              1.8985005923168177
# killPlace :          25.400477943879626
# kills :              11.578600417873002
# killStreaks :        8.278981250436104
# longestKill :        2.025944159652412
# maxPlace :           742.3279425303922
# numGroups :          709.7142573881279
# revives :            1.3270048683373787
# rideDistance :       1.5831084180068284
# roadKills :          1.0235960677025837
# swimDistance :       1.0546358617003588
# teamKills :          1.0679204251680088
# vehicleDestroys :    1.0544302160127654
# walkDistance :       7.0749053686938765
# weaponsAcquired :    5.7855252541842175

# %%
plt.figure(figsize = (20, 12))
sns.heatmap(temp_data.corr(), 
            annot = True,            # 숫자(상관계수) 표기 여부
            fmt = '.3f',             # 숫자 포멧 : 소수점 3자리까지 표기
            cmap = 'RdYlBu_r',       # 칼라맵
            vmin = -1, vmax = 1)     # 값의 최소, 최대값값
plt.xticks(rotation = 30)
plt.show()

# %%
temp_data_2 = temp_data.copy()
remove_list = ['numGroups', 'killPlace', 'damageDealt', 'killStreaks']

temp_data_2.drop(remove_list, axis = 1, inplace = True)

# 다중공선성 - > 최종 변수 선택
for i, column in enumerate(temp_data_2.loc[:,:'weaponsAcquired']) :
    print(f"{column} : ".ljust(20),variance_inflation_factor(temp_data_2.values, i))
# Out:
# assists :            1.4645990238677513
# boosts :             3.31664385585865
# DBNOs :              5.4129878871809245
# headshotKills :      2.056713686520467
# heals :              1.8932611400915345
# kills :              6.996151734390941
# longestKill :        2.0218408791029816
# maxPlace :           4.269406864235175
# revives :            1.3252173419062296
# rideDistance :       1.581972613783241
# roadKills :          1.0227402020110954
# swimDistance :       1.0544883421505127
# teamKills :          1.0622254526365758
# vehicleDestroys :    1.0533989422635037
# walkDistance :       7.072562252506514
# weaponsAcquired :    5.691885500699967

# %%
data_input = temp_data_2
data_input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 626526 entries, 8 to 4446952
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   assists          626526 non-null  int64
#  1   boosts           626526 non-null  int64
#  2   DBNOs            626526 non-null  int64
#  3   headshotKills    626526 non-null  int64
#  4   heals            626526 non-null  int64
#  5   kills            626526 non-null  int64
#  6   longestKill      626526 non-null  float64
#  7   maxPlace         626526 non-null  int64
#  8   revives          626526 non-null  int64
#  9   rideDistance     626526 non-null  float64
#  10  roadKills        626526 non-null  int64
#  11  swimDistance     626526 non-null  float64
#  12  teamKills        626526 non-null  int64
#  13  vehicleDestroys  626526 non-null  int64
#  14  walkDistance     626526 non-null  float64
#  15  weaponsAcquired  626526 non-null  int64
#  16  winPlacePerc     626526 non-null  float64
# dtypes: float64(5), int64(12)
# memory usage: 102.2 MB

# %%
# 이상치 제거를 위한...
# 무기흭득과 부스트 사용횟수가 높게 나옴.. 이 둘의 이상치를 제거 해보자
plt.figure(figsize = (20, 12))
sns.heatmap(data_input.corr(), 
            annot = True,            # 숫자(상관계수) 표기 여부
            fmt = '.3f',             # 숫자 포멧 : 소수점 3자리까지 표기
            cmap = 'RdYlBu_r',       # 칼라맵
            vmin = -1, vmax = 1)     # 값의 최소, 최대값값
plt.xticks(rotation = 30)
plt.show()

# %%
fig, axs = plt.subplots(2,1, figsize = (15,10))
sns.boxplot(x = 'weaponsAcquired', y = 'winPlacePerc', data = data_input, ax = axs[0])
axs[0].set_title('weaponsAcquired / winPlacePerc')

plt.subplots_adjust(hspace = 0.35)
sns.boxplot(x = 'boosts', y = 'winPlacePerc', data = data_input, ax = axs[1])
axs[1].set_title('boosts / winPlacePerc')
# Out:
# Text(0.5, 1.0, 'boosts / winPlacePerc')

# %%
copy_input = data_input.copy()
plt.figure(figsize=(15,8))
copy_input['walkDistance_range'] = pd.cut(copy_input['walkDistance'], 60)
sns.boxplot(x = 'walkDistance_range', y = 'winPlacePerc', data = copy_input)

plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * 이동거리를 범주로 나누어 박스플롯으로 그려보니 이동거리가 무척짧은데 승률이 높은 것을 발견 !

# %% [markdown]
# * 무기흭득을 하지 않았는데 이겼던 적이 있다.. ? 핵으로 의심될수 밖에 없기에 이상치로 판단

# %%
# 이상치 upper fence값 제거 함수
def remove_outlier(data, col, remove_cg_value) :  # remove_cg_value는 이상치 제거할 범주값
    outlier_column_data = data['winPlacePerc'].loc[data[col] == remove_cg_value]
    quan_25 = np.percentile(outlier_column_data.values, 25)
    quan_75 = np.percentile(outlier_column_data.values, 75)
    
    iqr = quan_75 - quan_25
    max_value = (1.5 * iqr) + quan_75
    
    outlier_index = data['winPlacePerc'].loc[(data['winPlacePerc'] > max_value) & (data[col] == remove_cg_value)].index
    print("outlier length : ",len(outlier_index))
    data.drop(outlier_index, axis = 0,inplace=True)
    
    return data

# %%
# 이상치 제거
data_copy = data_input.copy()
data_copy = remove_outlier(data_copy, 'weaponsAcquired',0)
data_copy = remove_outlier(data_copy, 'boosts',0)

remove_index = data_copy.loc[data_copy['walkDistance'] == 0.0].index
print("outlier length : ",len(remove_index))
data_copy.drop(remove_index, axis = 0, inplace = True)

# 박스 플롯
fig, axs = plt.subplots(2,1, figsize = (15,10))
sns.boxplot(x = 'weaponsAcquired', y = 'winPlacePerc', data = data_copy, ax = axs[0])
axs[0].set_title('weaponsAcquired / winPlacePerc')

plt.subplots_adjust(hspace = 0.35)
sns.boxplot(x = 'boosts', y = 'winPlacePerc', data = data_copy, ax = axs[1])
axs[1].set_title('boosts / winPlacePerc')

plt.figure(figsize = (20, 12))
sns.heatmap(data_copy.corr(), 
            annot = True,            # 숫자(상관계수) 표기 여부
            fmt = '.3f',             # 숫자 포멧 : 소수점 3자리까지 표기
            cmap = 'RdYlBu_r',       # 칼라맵
            vmin = -1, vmax = 1)     # 값의 최소, 최대값값
plt.xticks(rotation = 30)
plt.show()

# 타켓 입력 데이터 나누기
final_target = data_copy['winPlacePerc']
final_input = data_copy.loc[:,:'weaponsAcquired']

print("")
print(final_input.info())
print("-"*50)
print(final_target.info())
# Out:
# outlier length :  4438
# outlier length :  6634
# outlier length :  13953
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 601501 entries, 8 to 4446952
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   assists          601501 non-null  int64
#  1   boosts           601501 non-null  int64
#  2   DBNOs            601501 non-null  int64
#  3   headshotKills    601501 non-null  int64
#  4   heals            601501 non-null  int64
#  5   kills            601501 non-null  int64
#  6   longestKill      601501 non-null  float64
#  7   maxPlace         601501 non-null  int64
#  8   revives          601501 non-null  int64
#  9   rideDistance     601501 non-null  float64
#  10  roadKills        601501 non-null  int64
#  11  swimDistance     601501 non-null  float64
#  12  teamKills        601501 non-null  int64
#  13  vehicleDestroys  601501 non-null  int64
#  14  walkDistance     601501 non-null  float64
#  15  weaponsAcquired  601501 non-null  int64
# dtypes: float64(4), int64(12)
# memory usage: 78.0 MB
# None
# --------------------------------------------------
# <class 'pandas.core.series.Series'>
# Int64Index: 601501 entries, 8 to 4446952
# Series name: winPlacePerc
# Non-Null Count   Dtype
# --------------   -----
# 601501 non-null  float64
# dtypes: float64(1)
# memory usage: 9.2 MB
# None

# %%
# 훈련세트 테스트 세트 나누기
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(final_input, final_target, random_state = 42)

# %%
# 하이퍼파라미터 튜닝 - LASSO 회귀
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

params = { 'alpha' : [0.01, 0.1, 1, 10],
           'max_iter' : [1000,1500,2000,2500]
         }

# %%
gs = GridSearchCV(Lasso(), params, n_jobs = -1)
gs.fit(train_input, train_target)
# Out:
# GridSearchCV(estimator=Lasso(), n_jobs=-1,
#              param_grid={'alpha': [0.01, 0.1, 1, 10],
#                          'max_iter': [1000, 1500, 2000, 2500]})

# %%
# 검증점수 가장 높은 모델 파라미터 조합
print(gs.best_params_)

#각 매개변수에서 수행한 교차 검증 평균 점수
print(gs.cv_results_['mean_test_score'])

print("-"*50)

# 가장 좋은 파라미터 조합 모델
dt = gs.best_estimator_
print("test score : ", dt.score(test_input, test_target))
# Out:
# {'alpha': 0.01, 'max_iter': 1000}
# [0.71984142 0.71984142 0.71984142 0.71984142 0.68728456 0.68728456
#  0.68728456 0.68728456 0.68362182 0.68362182 0.68362182 0.68362182
#  0.68024729 0.68024729 0.68024729 0.68024729]
# --------------------------------------------------
# test score :  0.7229020316668094

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_validate

# %%
gbr = GradientBoostingRegressor(n_estimators=100, learning_rate=0.2, max_depth= 10, random_state = 42)
gbr.fit(train_input, train_target)
# Out:
# GradientBoostingRegressor(learning_rate=0.2, max_depth=10, random_state=42)

# %%
print(gbr.score(test_input, test_target))
# Out:
# 0.7758165987425517
